# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !nvcc --version
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0359fe98-ff36-4574-8ff4-b59735a98a3f" name="files[]" multiple disabled />
#      <output id="result-0359fe98-ff36-4574-8ff4-b59735a98a3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving custom_layers.py to custom_layers.py
# Saving dataset.py to dataset.py
# Saving util.py to util.py

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

import util
import dataset as dset

# %%
class generator(nn.Module):

    def __init__(self, dim_noise=100, dim_output_img=64, n_channel=3):
        super(generator, self).__init__()

        inplace = True
        init_kernel_sise = int(dim_output_img / (2 ** 5))
        
        self.conv_trans_2d1 = nn.ConvTranspose2d(dim_noise, dim_output_img*8, init_kernel_sise, 1, 0, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(dim_output_img*8)
        self.relu1 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d2 = nn.ConvTranspose2d(dim_output_img*8, dim_output_img*4, 4, 2,1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(dim_output_img*4)
        self.relu2 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d3 = nn.ConvTranspose2d(dim_output_img*4, dim_output_img*2,  4,2,1, bias=False)
        self.batchnorm3 = nn.BatchNorm2d(dim_output_img*2)
        self.relu3 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d4 = nn.ConvTranspose2d(dim_output_img*2, dim_output_img, 4,2,1, bias=False)
        self.batchnorm4 = nn.BatchNorm2d(dim_output_img)
        self.relu4 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d5 = nn.ConvTranspose2d(dim_output_img, dim_output_img, 4,2,1, bias=False)
        self.batchnorm5 = nn.BatchNorm2d(dim_output_img)
        self.relu5 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d6 = nn.ConvTranspose2d(dim_output_img, n_channel, 4,2,1, bias=False)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.relu1(self.batchnorm1(self.conv_trans_2d1(x)))
        x = self.relu2(self.batchnorm2(self.conv_trans_2d2(x)))
        x = self.relu3(self.batchnorm3(self.conv_trans_2d3(x)))
        x = self.relu4(self.batchnorm4(self.conv_trans_2d4(x)))
        x = self.relu5(self.batchnorm5(self.conv_trans_2d5(x)))
        x = self.tanh(self.conv_trans_2d6(x))
        return x

# %%
class discriminator(nn.Module):

    def __init__(self, dim_input_img=64, n_channel = 3):
        super(discriminator, self).__init__()

        slope = 0.2
        inplace = True
        final_ker_size = int(dim_input_img / (2**4))
        
        self.conv1 = nn.Conv2d(n_channel, dim_input_img, 4, 2,1, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(dim_input_img)
        self.lrelu1 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv2 = nn.Conv2d(dim_input_img, dim_input_img * 2, 4, 2,1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(dim_input_img * 2)
        self.lrelu2 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv3 = nn.Conv2d(dim_input_img * 2, dim_input_img * 4, 4, 2,1, bias=False)
        self.batchnorm3 = nn.BatchNorm2d(dim_input_img * 4)
        self.lrelu3 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        # self.conv4 = nn.Conv2d(dim_input_img * 4, dim_input_img * 4, 4, 2,1, bias=False)
        # self.batchnorm4 = nn.BatchNorm2d(dim_input_img * 4)
        # self.lrelu4 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv5 = nn.Conv2d(dim_input_img * 4, dim_input_img * 8, 4, 2,1, bias=False)
        self.batchnorm5 = nn.BatchNorm2d(dim_input_img * 8)
        self.lrelu5 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv6 = nn.Conv2d(dim_input_img * 8, 1, final_ker_size, 1, 0, bias=False)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.lrelu1(self.batchnorm1(self.conv1(x)))
        x = self.lrelu2(self.batchnorm2(self.conv2(x)))
        x = self.lrelu3(self.batchnorm3(self.conv3(x)))
        # x = self.lrelu4(self.batchnorm4(self.conv4(x)))
        x = self.lrelu5(self.batchnorm5(self.conv5(x)))
        x = self.sig(self.conv6(x))
        return x

# %%
class generator_128(nn.Module):

    def __init__(self, dim_noise=100, dim_output_img=64, n_channel=3):
        super(generator_128, self).__init__()

        inplace = True
        num_reduce_half=5
        init_kernel_sise = int(dim_output_img / (2 ** num_reduce_half))
        
        self.conv_trans_2d0 = nn.ConvTranspose2d(dim_noise, dim_output_img*16, init_kernel_sise, 1, 0, bias=False)
        self.selu0 = nn.SELU(inplace=inplace)
        
        self.conv_trans_2d1 = nn.ConvTranspose2d(dim_output_img*16, dim_output_img*8, 4, 2, 1, bias=False)
        self.selu1 = nn.SELU(inplace=inplace)

        self.conv_trans_2d2 = nn.ConvTranspose2d(dim_output_img*8, dim_output_img*4, 4, 2,1, bias=False)
        self.selu2 = nn.SELU(inplace=inplace)

        self.conv_trans_2d3 = nn.ConvTranspose2d(dim_output_img*4, dim_output_img*2,  4,2,1, bias=False)
        self.selu3 = nn.SELU(inplace=inplace)

        self.conv_trans_2d4 = nn.ConvTranspose2d(dim_output_img*2, dim_output_img, 4,2,1, bias=False)
        self.selu4 = nn.SELU(inplace=inplace)

        self.conv_trans_2d6 = nn.ConvTranspose2d(dim_output_img, n_channel, 4,2,1, bias=False)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.selu0(self.conv_trans_2d0(x))
        x = self.selu1(self.conv_trans_2d1(x))
        x = self.selu2(self.conv_trans_2d2(x))
        x = self.selu3(self.conv_trans_2d3(x))
        x = self.selu4(self.conv_trans_2d4(x))
        x = self.tanh(self.conv_trans_2d6(x))
        return x


class discriminator_128(nn.Module):

    def __init__(self, dim_input_img=64, n_channel = 3):
        super(discriminator_128, self).__init__()

        # slope = 0.2
        inplace = True
        num_reduce_half=5
        final_ker_size = int(dim_input_img / (2**num_reduce_half))
        
        self.conv1 = nn.Conv2d(n_channel, dim_input_img, 4, 2,1, bias=False)
        self.selu1 = nn.SELU(inplace=inplace)

        self.conv2 = nn.Conv2d(dim_input_img, dim_input_img * 2, 4, 2,1, bias=False)
        self.selu2 = nn.SELU(inplace=inplace)

        self.conv3 = nn.Conv2d(dim_input_img * 2, dim_input_img * 4, 4, 2,1, bias=False)
        self.selu3 = nn.SELU(inplace=inplace)

        self.conv4 = nn.Conv2d(dim_input_img * 4, dim_input_img * 8, 4, 2,1, bias=False)
        self.selu4 = nn.SELU(inplace=inplace)

        self.conv5 = nn.Conv2d(dim_input_img * 8, dim_input_img * 16, 4, 2,1, bias=False)
        self.selu5 = nn.SELU(inplace=inplace)

        self.conv6 = nn.Conv2d(dim_input_img * 16, 1, final_ker_size, 1, 0, bias=False)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.selu1(self.conv1(x))
        x = self.selu2(self.conv2(x))
        x = self.selu3(self.conv3(x))
        x = self.selu4(self.conv4(x))
        x = self.selu5(self.conv5(x))
        x = self.sig(self.conv6(x))
        return x

# %%
def train_base(epochs, batch_size, dim_noise, device, dataset, generator, discriminator, loss, optimizer_gen, optimizer_dis, filepath=None):
    # load the data
    worker = 2
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=worker)
    
    # create the list to store each loss
    loss_list, score_list, img_list = [], [], []
    num_fixed_ns_img = 64
    fixed_noise = torch.randn(num_fixed_ns_img, dim_noise, 1, 1, device=device)

    # start iterating the epoch
    for e in range(epochs):
        loss_dis, loss_gen, score_dis_real, score_dis_fake, score_gen = 0, 0, 0, 0, 0

        for i, data in enumerate(dataloader):
            b_size = batch_size
            if len(data[0]) < batch_size:
                b_size = len(data[0])
            # ---------------------------
            # 1. Train the discriminator
            # ---------------------------
            # generate noise samples from the generator
            batch_noise = torch.randn(b_size, dim_noise, 1, 1, device=device)
            fake_data = generator(batch_noise)

            # start to train the discriminator
            discriminator.zero_grad()
            # calculate the loss of the noise samples, which assigns the same label 0
            # for all the samples, and get the single output(marks) from the discriminator
            output = discriminator(fake_data.detach()).view(-1) # use .detach() to stop the requirement of gradient
            label = torch.full((b_size,), 0, device=device)
            loss_d_ns = loss(output, label)
            loss_d_ns.backward()
            score_dis_fake = output.mean().item()
            
            # calculate the loss of the real samples and assigns label 1 to represent
            # all samples are true and get the single output(marks) from the discriminator
            read_data = data[0].to(device)
            output = discriminator(read_data).view(-1)
            label.fill_(1)
            loss_d_real = loss(output, label)
            loss_d_real.backward()
            score_dis_real = output.mean().item()

            loss_d = loss_d_ns + loss_d_real
            loss_dis = loss_d.item()
            optimizer_dis.step()

            # ---------------------------
            # 2. Train the generator
            # ---------------------------
            # Feed the noise samplea to the discriminator agian to geit the accurate scores
            # after training the discriminator, and assign label 1 not to see the noise as
            # real label but to let the loss function to be correct and do correct back propogation
            generator.zero_grad()            
            # batch_noise = util.torch.randn(b_size, dim_noise)
            # fake_data = generator(batch_noise)
            output = discriminator(fake_data).view(-1)
            loss_g = loss(output, label)
            loss_g.backward()
            score_gen = output.mean().item()
            loss_gen = loss_g.item()
            optimizer_gen.step()


            # print information to the console
            # print information 5 times in a epoch
            num2print = 20
            if (i + 1) % num2print == 0:
                print('epoch: %d, iter: %d, loss_D: %.4f, loss_G: %.4f;\t Scores: train D: D(x): %.4f, D(G(z)): %.4f train G: D(G(z))： %.4f'
                        % (e, (i + 1), loss_dis, loss_gen, score_dis_real, score_dis_fake, score_gen))           
                
                # store the final loss for D and G for a specific time interval of a whole epoch
                loss_list.append([loss_dis, loss_gen])
                # store the final score from D for noise and real samples for a specific time imterval on current epoch
                score_list.append([score_dis_fake, score_dis_real, score_gen])

        loss_list.append([loss_dis, loss_gen])
        score_list.append([score_dis_fake, score_dis_real, score_gen])
        # store the image that the generator create for each epoch
        test_img = generator(fixed_noise).detach().cpu()
        img_list.append(test_img.numpy())

        # save the model
        if (e+1) % 5 == 0:
            util.save_checkpoint(e+1, generator, discriminator, filepath)
    
    loss_list = list(map(list, zip(*loss_list)))
    score_list = list(map(list, zip(*score_list)))
        
    return generator, discriminator, loss_list, score_list, img_list

# %%
def build_gen_dis(config):
    if config.DIM_IMG == 64:
        net_gen = generator(config.DIM_NOISE, config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
        net_dis = discriminator(config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
    elif config.DIM_IMG == 128:
        net_gen = generator_128(config.DIM_NOISE, config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
        net_dis = discriminator_128(config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)

    if config.INIT:
        net_gen.apply(init_weight)
        net_dis.apply(init_weight)
    else:
        ext = config.PATH_MODEL[-4]
        path_model = config.PATH_MODEL[:-4] + '_epoch_%d' + ext % config.IMPORT_IDX_EPOCH
        net_gen, net_dis = util.load_checkpoint(config.EPOCHS, net_gen, net_dis, path_model)

    return net_gen, net_dis

def train(dataset, net_gen, net_dis, config):
    # config = config.config_dcgan
    # net_gen = generator(config.DIM_NOISE, config.DIM_IMG).to(config.DEVICE)
    # net_dis = discriminator(config.DIM_IMG).to(config.DEVICE)
    
    loss = nn.BCELoss()
    optim_gen = optim.Adam(net_gen.parameters(), lr=config.LEARNING_RATE, betas=(config.MOMENTUM, 0.99))
    optim_dis = optim.Adam(net_dis.parameters(), lr=config.LEARNING_RATE, betas=(config.MOMENTUM, 0.99))

    net_gen, net_dis, losses, _, imgs = train_base(config.EPOCHS, config.BATCH_SIZE, config.DIM_NOISE, config.DEVICE,
                                                    dataset, net_gen, net_dis, loss, optim_gen, optim_dis, config.PATH_MODEL)
    
    return net_gen, net_dis, losses, imgs

# %%
def init_weight(layer):
    std = 0.02
    if type(layer) == nn.ConvTranspose2d:
        nn.init.normal_(layer.weight.data, mean=0, std=std)
    elif type(layer) == nn.Conv2d:
        nn.init.normal_(layer.weight.data, mean=0, std=std)
    elif type(layer) == nn.BatchNorm2d:
        nn.init.normal_(layer.weight.data, mean=1, std=std)
        nn.init.constant_(layer.bias.data, 0)

# %%
PATH_IMAGE = '/content/gdrive/My Drive/data/image_128'
PATH_IMAGE_FACE = '/content/gdrive/My Drive/data/anime-faces'
PATH_TAG = '/content/gdrive/My Drive/data/tags'
ARTWORK_TYPE = os.listdir(PATH_IMAGE)
IS_ADD_I2V_TAG = False

class config_dcgan():
    PATH_MODEL = '/content/gdrive/My Drive/data/model/dcgan_anime_face.pth'
    BATCH_SIZE = 64
    N_CHANNAL = 3
    DIM_IMG = 64
    DIM_NOISE = 100
    LEARNING_RATE = 0.0002
    MOMENTUM = 0.5
    EPOCHS = 50
    INIT = True
    IMPORT_IDX_EPOCH = EPOCHS
    DEVICE = torch.device("cuda:0")

# %%
f_minst = dset.fmnist('content/gdrive/My Drive/data/Fashion-MNIST', download=True, image_size=config_dcgan.DIM_IMG)

transform=transforms.Compose([transforms.Resize(64), transforms.ToTensor()])
anime = dset.animeFaceDataset(PATH_IMAGE_FACE, transform=transform)

dataset = dset.pokemonDataset(PATH_IMAGE, PATH_TAG, ARTWORK_TYPE, IS_ADD_I2V_TAG)

"""
mean, std = get_channel_mean_std(dataset, DIM_IMG)
     
print(mean)
print(std)
"""
mean = [220.43362509, 217.50907014, 212.78514176]
std = [71.7985852,  73.64374336, 78.23258064]
transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])])
dataset.set_transform(transform)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 26427392it [00:01, 13883263.34it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 96028.56it/s]
# 0it [00:00, ?it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 4423680it [00:01, 3928814.52it/s]
# 0it [00:00, ?it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 31565.53it/s]
# 0it [00:00, ?it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/train/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 26427392it [00:01, 13397829.33it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 89024.73it/s]
# 0it [00:00, ?it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 4423680it [00:01, 3973483.93it/s]
# 0it [00:00, ?it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 32080.63it/s]
# Extracting content/gdrive/My Drive/data/Fashion-MNIST/test/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
CONFIG = config_dcgan
net_gen, net_dis = build_gen_dis(CONFIG)
_, _, losses, imgs = train(anime, net_gen, net_dis, CONFIG)
# Out:
# epoch: 0, iter: 20, loss_D: 0.0288, loss_G: 7.7134;	 Scores: train D: D(x): 0.9801, D(G(z)): 0.0066 train G: D(G(z))： 0.0007
# epoch: 0, iter: 40, loss_D: 0.0396, loss_G: 14.0218;	 Scores: train D: D(x): 0.9749, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 60, loss_D: 0.0000, loss_G: 45.7900;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 80, loss_D: 0.0000, loss_G: 45.7528;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 100, loss_D: 0.0396, loss_G: 45.6415;	 Scores: train D: D(x): 0.9855, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 120, loss_D: 0.0000, loss_G: 45.4440;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 140, loss_D: 0.0000, loss_G: 45.4410;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 160, loss_D: 0.0000, loss_G: 45.4504;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 180, loss_D: 0.0000, loss_G: 45.3613;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 200, loss_D: 0.0001, loss_G: 45.2998;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 220, loss_D: 0.0000, loss_G: 45.4131;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 240, loss_D: 0.0000, loss_G: 45.3216;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 260, loss_D: 0.0000, loss_G: 45.3831;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 280, loss_D: 0.0000, loss_G: 45.3864;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 300, loss_D: 0.0000, loss_G: 45.3959;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 320, loss_D: 0.0000, loss_G: 45.3619;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 340, loss_D: 0.0000, loss_G: 45.2473;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 360, loss_D: 0.0000, loss_G: 45.3595;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 380, loss_D: 0.0000, loss_G: 45.3271;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 400, loss_D: 0.0000, loss_G: 45.3647;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 420, loss_D: 0.0000, loss_G: 45.3564;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 440, loss_D: 0.0000, loss_G: 45.3676;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 460, loss_D: 0.0000, loss_G: 45.3175;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 480, loss_D: 0.0000, loss_G: 45.2611;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 500, loss_D: 0.0000, loss_G: 45.2100;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 520, loss_D: 0.0000, loss_G: 45.2870;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 540, loss_D: 0.0000, loss_G: 45.2581;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 560, loss_D: 0.0000, loss_G: 45.1971;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 580, loss_D: 0.0000, loss_G: 45.1071;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 600, loss_D: 0.0000, loss_G: 45.2705;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 620, loss_D: 0.0000, loss_G: 45.2001;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 640, loss_D: 0.0000, loss_G: 45.2270;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 660, loss_D: 0.0000, loss_G: 45.0698;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 680, loss_D: 0.0000, loss_G: 45.1572;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 700, loss_D: 0.0000, loss_G: 44.7658;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 720, loss_D: 0.0000, loss_G: 44.8911;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 740, loss_D: 0.0000, loss_G: 44.8544;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 760, loss_D: 0.0000, loss_G: 44.7603;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 780, loss_D: 0.0000, loss_G: 44.7261;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 800, loss_D: 0.0000, loss_G: 44.8223;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 820, loss_D: 0.0000, loss_G: 44.8489;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 840, loss_D: 0.0000, loss_G: 44.8301;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 860, loss_D: 0.0000, loss_G: 44.8114;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 880, loss_D: 0.0000, loss_G: 44.7805;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 900, loss_D: 0.0000, loss_G: 44.7994;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 920, loss_D: 0.0000, loss_G: 44.7523;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 940, loss_D: 0.0000, loss_G: 44.7834;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 960, loss_D: 0.0000, loss_G: 44.7358;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 980, loss_D: 0.0000, loss_G: 44.7179;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1000, loss_D: 0.0000, loss_G: 44.6132;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1020, loss_D: 0.0000, loss_G: 44.6625;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1040, loss_D: 0.0000, loss_G: 44.6104;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1060, loss_D: 0.0000, loss_G: 44.7082;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1080, loss_D: 0.0000, loss_G: 44.6271;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1100, loss_D: 0.0000, loss_G: 44.6092;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1120, loss_D: 0.0000, loss_G: 44.5003;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1140, loss_D: 0.0000, loss_G: 44.5642;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1160, loss_D: 0.0000, loss_G: 44.4425;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1180, loss_D: 0.0000, loss_G: 44.5137;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1200, loss_D: 0.0000, loss_G: 44.4642;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1220, loss_D: 0.0000, loss_G: 44.4828;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1240, loss_D: 0.0000, loss_G: 44.4084;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1260, loss_D: 0.0000, loss_G: 44.3917;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1280, loss_D: 0.0000, loss_G: 44.3257;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1300, loss_D: 0.0000, loss_G: 44.3595;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1320, loss_D: 0.0000, loss_G: 44.2475;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1340, loss_D: 0.0000, loss_G: 44.1836;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1360, loss_D: 0.0000, loss_G: 44.1656;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1380, loss_D: 0.0000, loss_G: 44.2074;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1400, loss_D: 0.0000, loss_G: 44.1235;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1420, loss_D: 0.0000, loss_G: 43.9946;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1440, loss_D: 0.0000, loss_G: 43.8367;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1460, loss_D: 0.0000, loss_G: 43.6312;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1480, loss_D: 0.0000, loss_G: 43.5805;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1500, loss_D: 0.0000, loss_G: 43.3332;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1520, loss_D: 0.0000, loss_G: 43.0351;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1540, loss_D: 0.0000, loss_G: 41.9265;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 0, iter: 1740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 20, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 40, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 60, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 80, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 760, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 780, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 800, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 820, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 840, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 860, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 880, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 900, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 920, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 940, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 960, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 980, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1000, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1020, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1040, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1060, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1080, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 1, iter: 1740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 20, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 40, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 60, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 80, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 760, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 780, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 800, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 820, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 840, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 860, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 880, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 900, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 920, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 940, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 960, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 980, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1000, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1020, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1040, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1060, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1080, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 2, iter: 1740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 20, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 40, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 60, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 80, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 760, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 780, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 800, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 820, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 840, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 860, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 880, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 900, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 920, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 940, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 960, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 980, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1000, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1020, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1040, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1060, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1080, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 3, iter: 1740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 20, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 40, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 60, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 80, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 4, iter: 560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# ...
# epoch: 14, iter: 1000, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1020, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1040, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1060, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1080, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 14, iter: 1740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 20, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 40, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 60, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 80, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 740, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 760, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 780, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 800, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 820, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 840, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 860, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 880, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 900, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 920, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 940, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 960, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 980, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1000, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1020, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1040, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1060, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1080, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1100, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1120, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1140, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1160, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1180, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1200, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1220, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1240, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1260, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1280, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1300, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1320, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1340, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1360, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1380, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1400, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1420, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1440, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1460, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1480, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1500, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1520, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1540, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1560, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1580, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1600, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1620, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1640, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1660, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1680, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1700, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000
# epoch: 15, iter: 1720, loss_D: 27.6310, loss_G: 0.0000;	 Scores: train D: D(x): 1.0000, D(G(z)): 1.0000 train G: D(G(z))： 1.0000

# %%
plt.figure(figsize=(10, 5))
plt.plot(losses[0], label = 'generator')
plt.plot(losses[1], label = 'discriminator')
plt.title('Loss of training the gennerator and discriminator')
plt.xlabel('loss')
plt.ylabel('process')
plt.legend()
plt.show()

for img in imgs[0:50]:
    grid_img = util.make_figure_grid(img, 8)
    plt.figure(figsize=(10,10))
    plt.imshow(grid_img)
plt.show()
