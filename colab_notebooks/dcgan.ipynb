# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !nvcc --version
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-176dec0c-0130-4621-bb13-a678b745638e" name="files[]" multiple disabled />
#      <output id="result-176dec0c-0130-4621-bb13-a678b745638e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

import util
import dataset as dset

# %%
class generator(nn.Module):

    def __init__(self, dim_noise=100, dim_output_img=64, n_channel=3):
        super(generator, self).__init__()

        inplace = True
        init_kernel_sise = int(dim_output_img / (2 ** 4))
        
        self.conv_trans_2d1 = nn.ConvTranspose2d(dim_noise, dim_output_img*8, init_kernel_sise, 1, 0, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(dim_output_img*8)
        self.relu1 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d2 = nn.ConvTranspose2d(dim_output_img*8, dim_output_img*4, 4, 2,1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(dim_output_img*4)
        self.relu2 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d3 = nn.ConvTranspose2d(dim_output_img*4, dim_output_img*2,  4,2,1, bias=False)
        self.batchnorm3 = nn.BatchNorm2d(dim_output_img*2)
        self.relu3 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d4 = nn.ConvTranspose2d(dim_output_img*2, dim_output_img, 4,2,1, bias=False)
        self.batchnorm4 = nn.BatchNorm2d(dim_output_img)
        self.relu4 = nn.ReLU(inplace=inplace)

        # self.conv_trans_2d5 = nn.ConvTranspose2d(dim_output_img, dim_output_img, 4,2,1, bias=False)
        # self.batchnorm5 = nn.BatchNorm2d(dim_output_img)
        # self.relu5 = nn.ReLU(inplace=inplace)

        self.conv_trans_2d6 = nn.ConvTranspose2d(dim_output_img, n_channel, 4,2,1, bias=False)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.relu1(self.batchnorm1(self.conv_trans_2d1(x)))
        x = self.relu2(self.batchnorm2(self.conv_trans_2d2(x)))
        x = self.relu3(self.batchnorm3(self.conv_trans_2d3(x)))
        x = self.relu4(self.batchnorm4(self.conv_trans_2d4(x)))
        # x = self.relu5(self.batchnorm5(self.conv_trans_2d5(x)))
        x = self.tanh(self.conv_trans_2d6(x))
        return x

# %%
class discriminator(nn.Module):

    def __init__(self, dim_input_img=64, n_channel = 3):
        super(discriminator, self).__init__()

        slope = 0.2
        inplace = True
        final_ker_size = int(dim_input_img / (2**4))
        
        self.conv1 = nn.Conv2d(n_channel, dim_input_img, 4, 2,1, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(dim_input_img)
        self.lrelu1 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv2 = nn.Conv2d(dim_input_img, dim_input_img * 2, 4, 2,1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(dim_input_img * 2)
        self.lrelu2 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv3 = nn.Conv2d(dim_input_img * 2, dim_input_img * 4, 4, 2,1, bias=False)
        self.batchnorm3 = nn.BatchNorm2d(dim_input_img * 4)
        self.lrelu3 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        # self.conv4 = nn.Conv2d(dim_input_img * 4, dim_input_img * 4, 4, 2,1, bias=False)
        # self.batchnorm4 = nn.BatchNorm2d(dim_input_img * 4)
        # self.lrelu4 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv5 = nn.Conv2d(dim_input_img * 4, dim_input_img * 8, 4, 2,1, bias=False)
        self.batchnorm5 = nn.BatchNorm2d(dim_input_img * 8)
        self.lrelu5 = nn.LeakyReLU(negative_slope=slope, inplace=inplace)

        self.conv6 = nn.Conv2d(dim_input_img * 8, 1, final_ker_size, 1, 0, bias=False)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.lrelu1(self.batchnorm1(self.conv1(x)))
        x = self.lrelu2(self.batchnorm2(self.conv2(x)))
        x = self.lrelu3(self.batchnorm3(self.conv3(x)))
        # x = self.lrelu4(self.batchnorm4(self.conv4(x)))
        x = self.lrelu5(self.batchnorm5(self.conv5(x)))
        x = self.sig(self.conv6(x))
        return x

# %%
class generator_128(nn.Module):

    def __init__(self, dim_noise=100, dim_output_img=64, n_channel=3):
        super(generator_128, self).__init__()

        inplace = True
        num_reduce_half=5
        init_kernel_sise = int(dim_output_img / (2 ** num_reduce_half))
        
        self.conv_trans_2d0 = nn.ConvTranspose2d(dim_noise, dim_output_img*16, init_kernel_sise, 1, 0, bias=False)
        self.selu0 = nn.SELU(inplace=inplace)
        
        self.conv_trans_2d1 = nn.ConvTranspose2d(dim_output_img*16, dim_output_img*8, 4, 2, 1, bias=False)
        self.selu1 = nn.SELU(inplace=inplace)

        self.conv_trans_2d2 = nn.ConvTranspose2d(dim_output_img*8, dim_output_img*4, 4, 2,1, bias=False)
        self.selu2 = nn.SELU(inplace=inplace)

        self.conv_trans_2d3 = nn.ConvTranspose2d(dim_output_img*4, dim_output_img*2,  4,2,1, bias=False)
        self.selu3 = nn.SELU(inplace=inplace)

        self.conv_trans_2d4 = nn.ConvTranspose2d(dim_output_img*2, dim_output_img, 4,2,1, bias=False)
        self.selu4 = nn.SELU(inplace=inplace)

        self.conv_trans_2d6 = nn.ConvTranspose2d(dim_output_img, n_channel, 4,2,1, bias=False)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.selu0(self.conv_trans_2d0(x))
        x = self.selu1(self.conv_trans_2d1(x))
        x = self.selu2(self.conv_trans_2d2(x))
        x = self.selu3(self.conv_trans_2d3(x))
        x = self.selu4(self.conv_trans_2d4(x))
        x = self.tanh(self.conv_trans_2d6(x))
        return x


class discriminator_128(nn.Module):

    def __init__(self, dim_input_img=64, n_channel = 3):
        super(discriminator_128, self).__init__()

        # slope = 0.2
        inplace = True
        num_reduce_half=5
        final_ker_size = int(dim_input_img / (2**num_reduce_half))
        
        self.conv1 = nn.Conv2d(n_channel, dim_input_img, 4, 2,1, bias=False)
        self.selu1 = nn.SELU(inplace=inplace)

        self.conv2 = nn.Conv2d(dim_input_img, dim_input_img * 2, 4, 2,1, bias=False)
        self.selu2 = nn.SELU(inplace=inplace)

        self.conv3 = nn.Conv2d(dim_input_img * 2, dim_input_img * 4, 4, 2,1, bias=False)
        self.selu3 = nn.SELU(inplace=inplace)

        self.conv4 = nn.Conv2d(dim_input_img * 4, dim_input_img * 8, 4, 2,1, bias=False)
        self.selu4 = nn.SELU(inplace=inplace)

        self.conv5 = nn.Conv2d(dim_input_img * 8, dim_input_img * 16, 4, 2,1, bias=False)
        self.selu5 = nn.SELU(inplace=inplace)

        self.conv6 = nn.Conv2d(dim_input_img * 16, 1, final_ker_size, 1, 0, bias=False)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.selu1(self.conv1(x))
        x = self.selu2(self.conv2(x))
        x = self.selu3(self.conv3(x))
        x = self.selu4(self.conv4(x))
        x = self.selu5(self.conv5(x))
        x = self.sig(self.conv6(x))
        return x

# %%
def train_base(epochs, batch_size, dim_noise, device, dataset, generator, discriminator, loss, optimizer_gen, optimizer_dis, filepath=None):
    # load the data
    worker = 2
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=worker)
    
    # create the list to store each loss
    loss_list, score_list, img_list = [], [], []
    num_fixed_ns_img = 64
    fixed_noise = torch.randn(num_fixed_ns_img, dim_noise, 1, 1, device=device)

    # start iterating the epoch
    for e in range(epochs):
        loss_dis, loss_gen, score_dis_real, score_dis_fake, score_gen = 0, 0, 0, 0, 0

        for i, data in enumerate(dataloader):
            b_size = batch_size
            if len(data[0]) < batch_size:
                b_size = len(data[0])
            # ---------------------------
            # 1. Train the discriminator
            # ---------------------------
            # generate noise samples from the generator
            batch_noise = torch.randn(b_size, dim_noise, 1, 1, device=device)
            fake_data = generator(batch_noise)

            # start to train the discriminator
            discriminator.zero_grad()
            # calculate the loss of the noise samples, which assigns the same label 0
            # for all the samples, and get the single output(marks) from the discriminator
            output = discriminator(fake_data.detach()).view(-1) # use .detach() to stop the requirement of gradient
            label = torch.full((b_size,), 0, device=device)
            loss_d_ns = loss(output, label)
            loss_d_ns.backward()
            score_dis_fake = output.mean().item()
            
            # calculate the loss of the real samples and assigns label 1 to represent
            # all samples are true and get the single output(marks) from the discriminator
            read_data = data[0].to(device)
            output = discriminator(read_data).view(-1)
            label.fill_(1)
            loss_d_real = loss(output, label)
            loss_d_real.backward()
            score_dis_real = output.mean().item()

            loss_d = loss_d_ns + loss_d_real
            loss_dis = loss_d.item()
            optimizer_dis.step()

            # ---------------------------
            # 2. Train the generator
            # ---------------------------
            # Feed the noise samplea to the discriminator agian to geit the accurate scores
            # after training the discriminator, and assign label 1 not to see the noise as
            # real label but to let the loss function to be correct and do correct back propogation
            generator.zero_grad()            
            # batch_noise = util.torch.randn(b_size, dim_noise)
            # fake_data = generator(batch_noise)
            output = discriminator(fake_data).view(-1)
            loss_g = loss(output, label)
            loss_g.backward()
            score_gen = output.mean().item()
            loss_gen = loss_g.item()
            optimizer_gen.step()


            # print information to the console
            # print information 5 times in a epoch
            num2print = 20
            if (i + 1) % num2print == 0:
                print('epoch: %d, iter: %d, loss_D: %.4f, loss_G: %.4f;\t Scores: train D: D(x): %.4f, D(G(z)): %.4f train G: D(G(z))： %.4f'
                        % (e, (i + 1), loss_dis, loss_gen, score_dis_real, score_dis_fake, score_gen))           
                
                # store the final loss for D and G for a specific time interval of a whole epoch
                loss_list.append([loss_dis, loss_gen])
                # store the final score from D for noise and real samples for a specific time imterval on current epoch
                score_list.append([score_dis_fake, score_dis_real, score_gen])

        loss_list.append([loss_dis, loss_gen])
        score_list.append([score_dis_fake, score_dis_real, score_gen])
        # store the image that the generator create for each epoch
        test_img = generator(fixed_noise).detach().cpu()
        img_list.append(test_img.numpy())

        # save the model
        if (e+1) % 5 == 0:
            util.save_checkpoint(e + 1, generator, discriminator,loss_list, filepath)
    
    loss_list = list(map(list, zip(*loss_list)))
    score_list = list(map(list, zip(*score_list)))
        
    return generator, discriminator, loss_list, score_list, img_list

# %%
def build_gen_dis(config):
    if config.DIM_IMG != 128:
        net_gen = generator(config.DIM_NOISE, config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
        net_dis = discriminator(config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
    elif config.DIM_IMG == 128:
        net_gen = generator_128(config.DIM_NOISE, config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)
        net_dis = discriminator_128(config.DIM_IMG, config.N_CHANNAL).to(config.DEVICE)

    if config.INIT:
        net_gen.apply(init_weight)
        net_dis.apply(init_weight)
        loss = None
    else:
        ext = config.PATH_MODEL[-4:]
        path_model = config.PATH_IMPORT_MODEL[:-4] + '_epoch_%d'  % config.IMPORT_IDX_EPOCH + ext
        net_gen, net_dis, loss = util.load_checkpoint(config.EPOCHS, net_gen, net_dis, path_model, config.DEVICE)

    return net_gen, net_dis, loss

def train(dataset, net_gen, net_dis, config):
    # config = config.config_dcgan
    # net_gen = generator(config.DIM_NOISE, config.DIM_IMG).to(config.DEVICE)
    # net_dis = discriminator(config.DIM_IMG).to(config.DEVICE)
    
    loss = nn.BCELoss()
    optim_gen = optim.Adam(net_gen.parameters(), lr=config.LEARNING_RATE, betas=(config.MOMENTUM, 0.99))
    optim_dis = optim.Adam(net_dis.parameters(), lr=config.LEARNING_RATE, betas=(config.MOMENTUM, 0.99))

    net_gen, net_dis, losses, _, imgs = train_base(config.EPOCHS, config.BATCH_SIZE, config.DIM_NOISE, config.DEVICE,
                                                    dataset, net_gen, net_dis, loss, optim_gen, optim_dis, config.PATH_MODEL)
    
    return net_gen, net_dis, losses, imgs

# %%
def init_weight(layer):
    std = 0.02
    if type(layer) == nn.ConvTranspose2d:
        nn.init.normal_(layer.weight.data, mean=0, std=std)
    elif type(layer) == nn.Conv2d:
        nn.init.normal_(layer.weight.data, mean=0, std=std)
    elif type(layer) == nn.BatchNorm2d:
        nn.init.normal_(layer.weight.data, mean=1, std=std)
        nn.init.constant_(layer.bias.data, 0)

# %%
PATH_IMAGE = '/content/gdrive/My Drive/data/image_64'
PATH_TAG = '/content/gdrive/My Drive/data/tags'
ARTWORK_TYPE = os.listdir(PATH_IMAGE)
IS_ADD_I2V_TAG = False

class config_dcgan():
    PATH_MODEL = '/content/gdrive/My Drive/data/yyf/model_yyf/dcgan_fminst_e50.pth'
    BATCH_SIZE = 64
    N_CHANNAL = 1
    DIM_IMG = 32
    DIM_NOISE = 100
    LEARNING_RATE = 0.0002
    MOMENTUM = 0.5
    EPOCHS = 50
    INIT = False
    IMPORT_IDX_EPOCH = 50
    PATH_IMPORT_MODEL = '/content/gdrive/My Drive/data/yyf/model_yyf/dcgan_fminst.pth'
    DEVICE = torch.device("cuda:0")

# %%
f_minst = dset.cifar10('content/gdrive/My Drive/data/Fashion-MNIST', download=True, image_size=config_dcgan.DIM_IMG)

# transform=transforms.Compose([transforms.Resize(64), transforms.ToTensor(), transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])])
# anime = dset.animeFaceDataset('/content/gdrive/My Drive/data/lr-anime-faces', transform=transform)

## dataset = dset.pokemonDataset(PATH_IMAGE, PATH_TAG, ARTWORK_TYPE, IS_ADD_I2V_TAG)

"""
mean, std = get_channel_mean_std(dataset, DIM_IMG)
     
print(mean)
print(std)
"""
# mean = [220.43362509, 217.50907014, 212.78514176]
# std = [71.7985852,  73.64374336, 78.23258064]
# transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])])
#transform=transforms.Compose([transforms.ToTensor()])
# dataset.set_transform(transform)
# Out:
# '\nmean, std = get_channel_mean_std(dataset, DIM_IMG)\n     \nprint(mean)\nprint(std)\n'

# %%
CONFIG = config_dcgan
net_gen, net_dis, loss = build_gen_dis(CONFIG)
print(net_gen)
print(net_dis)
print(loss)
_, _, losses, imgs = train(f_minst, net_gen, net_dis, CONFIG)
# Out:
# generator(
#   (conv_trans_2d1): ConvTranspose2d(100, 256, kernel_size=(2, 2), stride=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU(inplace)
#   (conv_trans_2d2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU(inplace)
#   (conv_trans_2d3): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU(inplace)
#   (conv_trans_2d4): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): ReLU(inplace)
#   (conv_trans_2d6): ConvTranspose2d(32, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (tanh): Tanh()
# )
# discriminator(
#   (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrelu1): LeakyReLU(negative_slope=0.2, inplace)
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrelu2): LeakyReLU(negative_slope=0.2, inplace)
#   (conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrelu3): LeakyReLU(negative_slope=0.2, inplace)
#   (conv5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lrelu5): LeakyReLU(negative_slope=0.2, inplace)
#   (conv6): Conv2d(256, 1, kernel_size=(2, 2), stride=(1, 1), bias=False)
#   (sig): Sigmoid()
# )
# [[0.24143001437187195, 4.100715160369873], [0.16327913105487823, 2.9065985679626465], [0.5410771369934082, 2.6487042903900146], [0.6401346921920776, 2.7972054481506348], [0.3183046579360962, 3.490312099456787], [0.15246263146400452, 2.983318328857422], [0.3366796374320984, 4.446491241455078], [0.2081582099199295, 3.541769504547119], [0.2944711446762085, 1.766271948814392], [0.5587095022201538, 3.4366328716278076], [0.5726995468139648, 3.2068088054656982], [0.3236004710197449, 3.4714102745056152], [0.37178707122802734, 2.362328052520752], [0.42084112763404846, 3.054384469985962], [0.47384020686149597, 2.9693400859832764], [0.3935486972332001, 2.682859182357788], [0.35199397802352905, 2.770848274230957], [0.4180387854576111, 2.813605785369873], [0.4206545948982239, 2.0966861248016357], [0.37822312116622925, 2.4798009395599365], [0.2973306179046631, 2.380844831466675], [0.47071588039398193, 2.813389778137
	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1040, loss_D: 0.0000, loss_G: 49.1397;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1060, loss_D: 0.0000, loss_G: 51.5267;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 0, iter: 1080, loss_D: 0.0000, loss_G: 50.5968;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 20, loss_D: 0.0000, loss_G: 50.7647;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 40, loss_D: 0.0000, loss_G: 50.8028;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 60, loss_D: 0.0000, loss_G: 50.4863;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 80, loss_D: 0.0000, loss_G: 50.4014;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 100, loss_D: 0.0000, loss_G: 49.5607;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 120, loss_D: 0.0000, loss_G: 50.9688;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 140, loss_D: 0.0000, loss_G: 51.5362;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 160, loss_D: 0.0000, loss_G: 49.9541;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 180, loss_D: 0.0000, loss_G: 50.7366;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 200, loss_D: 0.0000, loss_G: 49.8721;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 220, loss_D: 0.0000, loss_G: 50.2917;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 240, loss_D: 0.0000, loss_G: 49.7139;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 260, loss_D: 0.0000, loss_G: 49.4697;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 280, loss_D: 0.0000, loss_G: 49.5798;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 300, loss_D: 0.0000, loss_G: 50.8865;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 320, loss_D: 0.0000, loss_G: 50.1481;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 340, loss_D: 0.0000, loss_G: 50.5734;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 360, loss_D: 0.0000, loss_G: 50.5251;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 380, loss_D: 0.0000, loss_G: 51.0908;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 400, loss_D: 0.0000, loss_G: 49.2386;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 420, loss_D: 0.0000, loss_G: 49.9659;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 440, loss_D: 0.0000, loss_G: 49.9777;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 460, loss_D: 0.0000, loss_G: 48.9351;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 480, loss_D: 0.0000, loss_G: 49.2591;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 500, loss_D: 0.0000, loss_G: 49.6344;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 520, loss_D: 0.0000, loss_G: 49.4658;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 540, loss_D: 0.0000, loss_G: 49.3713;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 560, loss_D: 0.0000, loss_G: 50.2401;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 580, loss_D: 0.0000, loss_G: 50.3808;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 600, loss_D: 0.0000, loss_G: 50.2931;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 620, loss_D: 0.0000, loss_G: 50.4851;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 640, loss_D: 0.0000, loss_G: 50.1988;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 660, loss_D: 0.0000, loss_G: 49.7865;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 680, loss_D: 0.0000, loss_G: 50.2972;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 700, loss_D: 0.0000, loss_G: 49.7151;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 720, loss_D: 0.0000, loss_G: 50.5582;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 740, loss_D: 0.0000, loss_G: 48.0353;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 760, loss_D: 0.0000, loss_G: 49.0121;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 780, loss_D: 0.0000, loss_G: 49.1174;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 800, loss_D: 0.0000, loss_G: 49.8625;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 820, loss_D: 0.0000, loss_G: 49.4869;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 840, loss_D: 0.0000, loss_G: 49.1765;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 860, loss_D: 0.0000, loss_G: 48.5417;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 880, loss_D: 0.0000, loss_G: 48.7432;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 900, loss_D: 0.0000, loss_G: 48.9550;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 920, loss_D: 0.0000, loss_G: 43.8978;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 940, loss_D: 1.4316, loss_G: 42.2235;	 Scores: train D: D(x): 0.9986, D(G(z)): 0.4324 train G: D(G(z))： 0.0000
# epoch: 1, iter: 960, loss_D: 0.4512, loss_G: 22.7183;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.1827 train G: D(G(z))： 0.0000
# epoch: 1, iter: 980, loss_D: 0.0272, loss_G: 15.7401;	 Scores: train D: D(x): 0.9764, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 1000, loss_D: 0.0718, loss_G: 10.6266;	 Scores: train D: D(x): 0.9668, D(G(z)): 0.0006 train G: D(G(z))： 0.0003
# epoch: 1, iter: 1020, loss_D: 0.0186, loss_G: 8.4289;	 Scores: train D: D(x): 0.9971, D(G(z)): 0.0143 train G: D(G(z))： 0.0005
# epoch: 1, iter: 1040, loss_D: 0.0544, loss_G: 17.5569;	 Scores: train D: D(x): 0.9631, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 1, iter: 1060, loss_D: 0.0052, loss_G: 8.1415;	 Scores: train D: D(x): 0.9964, D(G(z)): 0.0012 train G: D(G(z))： 0.0008
# epoch: 1, iter: 1080, loss_D: 0.0039, loss_G: 7.1736;	 Scores: train D: D(x): 0.9991, D(G(z)): 0.0030 train G: D(G(z))： 0.0015
# epoch: 2, iter: 20, loss_D: 0.0572, loss_G: 11.1730;	 Scores: train D: D(x): 0.9963, D(G(z)): 0.0471 train G: D(G(z))： 0.0000
# epoch: 2, iter: 40, loss_D: 0.0069, loss_G: 7.2711;	 Scores: train D: D(x): 0.9969, D(G(z)): 0.0035 train G: D(G(z))： 0.0017
# epoch: 2, iter: 60, loss_D: 0.0136, loss_G: 7.8421;	 Scores: train D: D(x): 0.9962, D(G(z)): 0.0096 train G: D(G(z))： 0.0014
# epoch: 2, iter: 80, loss_D: 0.0008, loss_G: 9.0422;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0008 train G: D(G(z))： 0.0004
# epoch: 2, iter: 100, loss_D: 0.0211, loss_G: 8.7360;	 Scores: train D: D(x): 0.9858, D(G(z)): 0.0003 train G: D(G(z))： 0.0007
# epoch: 2, iter: 120, loss_D: 0.0018, loss_G: 8.1252;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0017 train G: D(G(z))： 0.0007
# epoch: 2, iter: 140, loss_D: 0.0000, loss_G: 12.1055;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 160, loss_D: 0.0046, loss_G: 8.0649;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0044 train G: D(G(z))： 0.0007
# epoch: 2, iter: 180, loss_D: 0.0005, loss_G: 9.4429;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0004 train G: D(G(z))： 0.0001
# epoch: 2, iter: 200, loss_D: 0.0003, loss_G: 9.2767;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0003 train G: D(G(z))： 0.0002
# epoch: 2, iter: 220, loss_D: 0.0084, loss_G: 7.7049;	 Scores: train D: D(x): 0.9931, D(G(z)): 0.0004 train G: D(G(z))： 0.0007
# epoch: 2, iter: 240, loss_D: 0.0189, loss_G: 5.0296;	 Scores: train D: D(x): 0.9842, D(G(z)): 0.0004 train G: D(G(z))： 0.0186
# epoch: 2, iter: 260, loss_D: 0.0003, loss_G: 13.0604;	 Scores: train D: D(x): 0.9997, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 280, loss_D: 0.0003, loss_G: 9.4581;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0002 train G: D(G(z))： 0.0002
# epoch: 2, iter: 300, loss_D: 0.0000, loss_G: 20.0269;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 320, loss_D: 0.0002, loss_G: 16.1267;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 340, loss_D: 0.0000, loss_G: 39.2599;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 360, loss_D: 0.0000, loss_G: 37.5932;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 380, loss_D: 0.0000, loss_G: 37.5885;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 400, loss_D: 0.0000, loss_G: 37.9105;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 420, loss_D: 0.0000, loss_G: 36.7207;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 2, iter: 440, loss_D: 0.0057, loss_G: 12.4348;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0056 train G: D(G(z))： 0.0002
# epoch: 2, iter: 460, loss_D: 0.0023, loss_G: 38.6000;	 Scores: train D: D(x): 0.9988, D(G(z)): 0.0010 train G: D(G(z))： 0.0007
# epoch: 2, iter: 480, loss_D: 0.0001, loss_G: 24.0594;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.
	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0002 train G: D(G(z))： 0.0002
# epoch: 5, iter: 280, loss_D: 0.0037, loss_G: 18.5011;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0036 train G: D(G(z))： 0.0014
# epoch: 5, iter: 300, loss_D: 0.0016, loss_G: 11.6542;	 Scores: train D: D(x): 0.9985, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 5, iter: 320, loss_D: 0.0214, loss_G: 7.1633;	 Scores: train D: D(x): 0.9907, D(G(z)): 0.0092 train G: D(G(z))： 0.0035
# epoch: 5, iter: 340, loss_D: 0.0128, loss_G: 7.1458;	 Scores: train D: D(x): 0.9980, D(G(z)): 0.0102 train G: D(G(z))： 0.0015
# epoch: 5, iter: 360, loss_D: 0.0025, loss_G: 8.7895;	 Scores: train D: D(x): 0.9980, D(G(z)): 0.0004 train G: D(G(z))： 0.0002
# epoch: 5, iter: 380, loss_D: 0.0008, loss_G: 13.3531;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0008 train G: D(G(z))： 0.0004
# epoch: 5, iter: 400, loss_D: 0.0011, loss_G: 8.7889;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0010 train G: D(G(z))： 0.0004
# epoch: 5, iter: 420, loss_D: 0.0081, loss_G: 8.0840;	 Scores: train D: D(x): 0.9930, D(G(z)): 0.0008 train G: D(G(z))： 0.0008
# epoch: 5, iter: 440, loss_D: 0.0052, loss_G: 7.5407;	 Scores: train D: D(x): 0.9991, D(G(z)): 0.0042 train G: D(G(z))： 0.0010
# epoch: 5, iter: 460, loss_D: 0.0149, loss_G: 7.3724;	 Scores: train D: D(x): 0.9874, D(G(z)): 0.0015 train G: D(G(z))： 0.0011
# epoch: 5, iter: 480, loss_D: 0.0126, loss_G: 6.6138;	 Scores: train D: D(x): 0.9980, D(G(z)): 0.0103 train G: D(G(z))： 0.0019
# epoch: 5, iter: 500, loss_D: 0.0019, loss_G: 7.3962;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0019 train G: D(G(z))： 0.0013
# epoch: 5, iter: 520, loss_D: 0.0001, loss_G: 16.1575;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0001 train G: D(G(z))： 0.0001
# epoch: 5, iter: 540, loss_D: 0.0067, loss_G: 8.2910;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0066 train G: D(G(z))： 0.0004
# epoch: 5, iter: 560, loss_D: 0.0341, loss_G: 8.2140;	 Scores: train D: D(x): 0.9708, D(G(z)): 0.0008 train G: D(G(z))： 0.0033
# epoch: 5, iter: 580, loss_D: 0.0177, loss_G: 7.0644;	 Scores: train D: D(x): 0.9948, D(G(z)): 0.0118 train G: D(G(z))： 0.0019
# epoch: 5, iter: 600, loss_D: 0.0006, loss_G: 13.3339;	 Scores: train D: D(x): 0.9997, D(G(z)): 0.0003 train G: D(G(z))： 0.0003
# epoch: 5, iter: 620, loss_D: 0.0044, loss_G: 9.4844;	 Scores: train D: D(x): 0.9970, D(G(z)): 0.0010 train G: D(G(z))： 0.0013
# epoch: 5, iter: 640, loss_D: 0.0805, loss_G: 19.9594;	 Scores: train D: D(x): 0.9567, D(G(z)): 0.0000 train G: D(G(z))： 0.0001
# epoch: 5, iter: 660, loss_D: 0.0039, loss_G: 9.7380;	 Scores: train D: D(x): 0.9974, D(G(z)): 0.0012 train G: D(G(z))： 0.0004
# epoch: 5, iter: 680, loss_D: 1.0543, loss_G: 7.9512;	 Scores: train D: D(x): 0.7443, D(G(z)): 0.0000 train G: D(G(z))： 0.0030
# epoch: 5, iter: 700, loss_D: 0.0011, loss_G: 10.1427;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0011 train G: D(G(z))： 0.0008
# epoch: 5, iter: 720, loss_D: 0.0021, loss_G: 8.7079;	 Scores: train D: D(x): 0.9989, D(G(z)): 0.0010 train G: D(G(z))： 0.0004
# epoch: 5, iter: 740, loss_D: 0.0017, loss_G: 7.5801;	 Scores: train D: D(x): 0.9993, D(G(z)): 0.0010 train G: D(G(z))： 0.0007
# epoch: 5, iter: 760, loss_D: 0.0025, loss_G: 21.3544;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0024 train G: D(G(z))： 0.0012
# epoch: 5, iter: 780, loss_D: 0.0320, loss_G: 10.5168;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0294 train G: D(G(z))： 0.0001
# epoch: 5, iter: 800, loss_D: 0.0106, loss_G: 8.8690;	 Scores: train D: D(x): 0.9923, D(G(z)): 0.0027 train G: D(G(z))： 0.0003
# epoch: 5, iter: 820, loss_D: 0.0053, loss_G: 7.6359;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0052 train G: D(G(z))： 0.0008
# epoch: 5, iter: 840, loss_D: 0.0624, loss_G: 10.4913;	 Scores: train D: D(x): 0.9755, D(G(z)): 0.0002 train G: D(G(z))： 0.0008
# epoch: 5, iter: 860, loss_D: 0.0019, loss_G: 17.1583;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0018 train G: D(G(z))： 0.0013
# epoch: 5, iter: 880, loss_D: 0.0011, loss_G: 13.2192;	 Scores: train D: D(x): 0.9989, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 5, iter: 900, loss_D: 0.1428, loss_G: 3.3556;	 Scores: train D: D(x): 0.8990, D(G(z)): 0.0069 train G: D(G(z))： 0.0601
# epoch: 5, iter: 920, loss_D: 0.0064, loss_G: 10.8907;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0062 train G: D(G(z))： 0.0015
# epoch: 5, iter: 940, loss_D: 0.0009, loss_G: 14.7374;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0008 train G: D(G(z))： 0.0017
# epoch: 5, iter: 960, loss_D: 0.0005, loss_G: 10.1365;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0004 train G: D(G(z))： 0.0004
# epoch: 5, iter: 980, loss_D: 0.0118, loss_G: 11.7765;	 Scores: train D: D(x): 0.9899, D(G(z)): 0.0001 train G: D(G(z))： 0.0001
# epoch: 5, iter: 1000, loss_D: 0.0310, loss_G: 27.5347;	 Scores: train D: D(x): 0.9852, D(G(z)): 0.0006 train G: D(G(z))： 0.0005
# epoch: 5, iter: 1020, loss_D: 0.0002, loss_G: 17.3432;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0001 train G: D(G(z))： 0.0001
# epoch: 5, iter: 1040, loss_D: 0.0036, loss_G: 8.9362;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0034 train G: D(G(z))： 0.0016
# epoch: 5, iter: 1060, loss_D: 0.0006, loss_G: 8.5872;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0005 train G: D(G(z))： 0.0004
# epoch: 5, iter: 1080, loss_D: 0.0072, loss_G: 7.6336;	 Scores: train D: D(x): 0.9947, D(G(z)): 0.0017 train G: D(G(z))： 0.0015
# epoch: 6, iter: 20, loss_D: 0.0125, loss_G: 9.2865;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0114 train G: D(G(z))： 0.0008
# epoch: 6, iter: 40, loss_D: 0.0017, loss_G: 7.9077;	 Scores: train D: D(x): 0.9997, D(G(z)): 0.0015 train G: D(G(z))： 0.0008
# epoch: 6, iter: 60, loss_D: 0.0006, loss_G: 12.1258;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0005 train G: D(G(z))： 0.0004
# epoch: 6, iter: 80, loss_D: 0.0089, loss_G: 10.9668;	 Scores: train D: D(x): 0.9917, D(G(z)): 0.0001 train G: D(G(z))： 0.0001
# epoch: 6, iter: 100, loss_D: 0.0317, loss_G: 34.7560;	 Scores: train D: D(x): 0.9744, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 6, iter: 120, loss_D: 0.0014, loss_G: 21.7576;	 Scores: train D: D(x): 0.9986, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# ...
# epoch: 47, iter: 760, loss_D: 0.0051, loss_G: 6.8317;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0051 train G: D(G(z))： 0.0030
# epoch: 47, iter: 780, loss_D: 0.0078, loss_G: 6.1382;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0077 train G: D(G(z))： 0.0048
# epoch: 47, iter: 800, loss_D: 0.0882, loss_G: 5.5918;	 Scores: train D: D(x): 0.9495, D(G(z)): 0.0240 train G: D(G(z))： 0.0090
# epoch: 47, iter: 820, loss_D: 0.0009, loss_G: 15.6876;	 Scores: train D: D(x): 0.9991, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 47, iter: 840, loss_D: 0.0011, loss_G: 11.1664;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0010 train G: D(G(z))： 0.0008
# epoch: 47, iter: 860, loss_D: 0.0020, loss_G: 8.7397;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0019 train G: D(G(z))： 0.0014
# epoch: 47, iter: 880, loss_D: 0.0013, loss_G: 9.0040;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0013 train G: D(G(z))： 0.0011
# epoch: 47, iter: 900, loss_D: 0.0096, loss_G: 5.4682;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0093 train G: D(G(z))： 0.0059
# epoch: 47, iter: 920, loss_D: 0.0016, loss_G: 13.8544;	 Scores: train D: D(x): 0.9984, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 47, iter: 940, loss_D: 0.0056, loss_G: 6.4356;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0054 train G: D(G(z))： 0.0025
# epoch: 47, iter: 960, loss_D: 0.0023, loss_G: 8.0417;	 Scores: train D: D(x): 0.9995, D(G(z)): 0.0018 train G: D(G(z))： 0.0010
# epoch: 47, iter: 980, loss_D: 0.0098, loss_G: 6.1672;	 Scores: train D: D(x): 0.9990, D(G(z)): 0.0088 train G: D(G(z))： 0.0035
# epoch: 47, iter: 1000, loss_D: 0.0468, loss_G: 7.0724;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0436 train G: D(G(z))： 0.0013
# epoch: 47, iter: 1020, loss_D: 0.0185, loss_G: 8.6515;	 Scores: train D: D(x): 0.9856, D(G(z)): 0.0005 train G: D(G(z))： 0.0004
# epoch: 47, iter: 1040, loss_D: 0.0019, loss_G: 8.1536;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0017 train G: D(G(z))： 0.0011
# epoch: 47, iter: 1060, loss_D: 0.0014, loss_G: 7.7329;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0014 train G: D(G(z))： 0.0008
# epoch: 47, iter: 1080, loss_D: 0.0125, loss_G: 5.7842;	 Scores: train D: D(x): 0.9988, D(G(z)): 0.0112 train G: D(G(z))： 0.0038
# epoch: 48, iter: 20, loss_D: 0.0392, loss_G: 6.3160;	 Scores: train D: D(x): 0.9932, D(G(z)): 0.0305 train G: D(G(z))： 0.0022
# epoch: 48, iter: 40, loss_D: 0.3320, loss_G: 2.7746;	 Scores: train D: D(x): 0.7999, D(G(z)): 0.0034 train G: D(G(z))： 0.2594
# epoch: 48, iter: 60, loss_D: 0.0023, loss_G: 7.4515;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0023 train G: D(G(z))： 0.0009
# epoch: 48, iter: 80, loss_D: 0.0386, loss_G: 6.7055;	 Scores: train D: D(x): 0.9934, D(G(z)): 0.0301 train G: D(G(z))： 0.0018
# epoch: 48, iter: 100, loss_D: 0.0130, loss_G: 8.6800;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0126 train G: D(G(z))： 0.0042
# epoch: 48, iter: 120, loss_D: 0.0253, loss_G: 6.2396;	 Scores: train D: D(x): 0.9825, D(G(z)): 0.0046 train G: D(G(z))： 0.0043
# epoch: 48, iter: 140, loss_D: 0.0228, loss_G: 7.7946;	 Scores: train D: D(x): 0.9993, D(G(z)): 0.0214 train G: D(G(z))： 0.0038
# epoch: 48, iter: 160, loss_D: 0.0339, loss_G: 6.3473;	 Scores: train D: D(x): 0.9985, D(G(z)): 0.0313 train G: D(G(z))： 0.0028
# epoch: 48, iter: 180, loss_D: 0.0088, loss_G: 7.9099;	 Scores: train D: D(x): 0.9920, D(G(z)): 0.0006 train G: D(G(z))： 0.0006
# epoch: 48, iter: 200, loss_D: 0.0067, loss_G: 6.2468;	 Scores: train D: D(x): 0.9985, D(G(z)): 0.0051 train G: D(G(z))： 0.0048
# epoch: 48, iter: 220, loss_D: 0.0308, loss_G: 5.5406;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0298 train G: D(G(z))： 0.0049
# epoch: 48, iter: 240, loss_D: 0.0103, loss_G: 5.8674;	 Scores: train D: D(x): 0.9930, D(G(z)): 0.0028 train G: D(G(z))： 0.0040
# epoch: 48, iter: 260, loss_D: 0.0176, loss_G: 5.8251;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0172 train G: D(G(z))： 0.0040
# epoch: 48, iter: 280, loss_D: 0.0581, loss_G: 7.3285;	 Scores: train D: D(x): 0.9550, D(G(z)): 0.0004 train G: D(G(z))： 0.0014
# epoch: 48, iter: 300, loss_D: 0.1077, loss_G: 15.0240;	 Scores: train D: D(x): 0.9229, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 48, iter: 320, loss_D: 0.0003, loss_G: 13.2994;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0001 train G: D(G(z))： 0.0000
# epoch: 48, iter: 340, loss_D: 0.0077, loss_G: 7.8090;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0076 train G: D(G(z))： 0.0011
# epoch: 48, iter: 360, loss_D: 0.0132, loss_G: 6.8546;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0130 train G: D(G(z))： 0.0019
# epoch: 48, iter: 380, loss_D: 0.0034, loss_G: 9.9595;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0032 train G: D(G(z))： 0.0022
# epoch: 48, iter: 400, loss_D: 0.0651, loss_G: 7.9247;	 Scores: train D: D(x): 0.9518, D(G(z)): 0.0003 train G: D(G(z))： 0.0011
# epoch: 48, iter: 420, loss_D: 0.0003, loss_G: 9.0297;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0003 train G: D(G(z))： 0.0002
# epoch: 48, iter: 440, loss_D: 0.0257, loss_G: 5.9255;	 Scores: train D: D(x): 0.9902, D(G(z)): 0.0150 train G: D(G(z))： 0.0054
# epoch: 48, iter: 460, loss_D: 0.0002, loss_G: 18.8737;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch:
	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0024 train G: D(G(z))： 0.0196
# epoch: 48, iter: 980, loss_D: 0.0164, loss_G: 6.7509;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0162 train G: D(G(z))： 0.0036
# epoch: 48, iter: 1000, loss_D: 0.0003, loss_G: 10.2057;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0002 train G: D(G(z))： 0.0002
# epoch: 48, iter: 1020, loss_D: 0.0005, loss_G: 9.2075;	 Scores: train D: D(x): 0.9997, D(G(z)): 0.0002 train G: D(G(z))： 0.0002
# epoch: 48, iter: 1040, loss_D: 0.0036, loss_G: 9.0949;	 Scores: train D: D(x): 0.9993, D(G(z)): 0.0028 train G: D(G(z))： 0.0012
# epoch: 48, iter: 1060, loss_D: 0.0140, loss_G: 8.2865;	 Scores: train D: D(x): 0.9893, D(G(z)): 0.0026 train G: D(G(z))： 0.0005
# epoch: 48, iter: 1080, loss_D: 0.0023, loss_G: 7.1783;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0022 train G: D(G(z))： 0.0018
# epoch: 49, iter: 20, loss_D: 0.0145, loss_G: 6.1782;	 Scores: train D: D(x): 0.9991, D(G(z)): 0.0133 train G: D(G(z))： 0.0049
# epoch: 49, iter: 40, loss_D: 0.1477, loss_G: 4.3982;	 Scores: train D: D(x): 0.9008, D(G(z)): 0.0021 train G: D(G(z))： 0.0404
# epoch: 49, iter: 60, loss_D: 0.0067, loss_G: 6.6481;	 Scores: train D: D(x): 0.9963, D(G(z)): 0.0030 train G: D(G(z))： 0.0026
# epoch: 49, iter: 80, loss_D: 0.0104, loss_G: 6.6352;	 Scores: train D: D(x): 0.9994, D(G(z)): 0.0097 train G: D(G(z))： 0.0029
# epoch: 49, iter: 100, loss_D: 0.0082, loss_G: 7.1060;	 Scores: train D: D(x): 0.9994, D(G(z)): 0.0074 train G: D(G(z))： 0.0025
# epoch: 49, iter: 120, loss_D: 0.0121, loss_G: 6.3655;	 Scores: train D: D(x): 0.9981, D(G(z)): 0.0100 train G: D(G(z))： 0.0029
# epoch: 49, iter: 140, loss_D: 0.0008, loss_G: 8.2603;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0008 train G: D(G(z))： 0.0005
# epoch: 49, iter: 160, loss_D: 0.0122, loss_G: 6.2267;	 Scores: train D: D(x): 0.9955, D(G(z)): 0.0071 train G: D(G(z))： 0.0032
# epoch: 49, iter: 180, loss_D: 0.0029, loss_G: 8.7562;	 Scores: train D: D(x): 0.9978, D(G(z)): 0.0007 train G: D(G(z))： 0.0005
# epoch: 49, iter: 200, loss_D: 0.0158, loss_G: 7.4962;	 Scores: train D: D(x): 0.9863, D(G(z)): 0.0011 train G: D(G(z))： 0.0014
# epoch: 49, iter: 220, loss_D: 0.0119, loss_G: 6.1640;	 Scores: train D: D(x): 0.9978, D(G(z)): 0.0093 train G: D(G(z))： 0.0039
# epoch: 49, iter: 240, loss_D: 0.0017, loss_G: 8.2099;	 Scores: train D: D(x): 0.9997, D(G(z)): 0.0014 train G: D(G(z))： 0.0005
# epoch: 49, iter: 260, loss_D: 0.0045, loss_G: 8.6909;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.
	 Scores: train D: D(x): 1.0000, D(G(z)): 0.1843 train G: D(G(z))： 0.0001
# epoch: 49, iter: 780, loss_D: 0.0540, loss_G: 5.7669;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0507 train G: D(G(z))： 0.0054
# epoch: 49, iter: 800, loss_D: 0.0002, loss_G: 15.0252;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 49, iter: 820, loss_D: 0.0208, loss_G: 16.7253;	 Scores: train D: D(x): 0.9812, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 49, iter: 840, loss_D: 0.0004, loss_G: 9.1440;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0003 train G: D(G(z))： 0.0002
# epoch: 49, iter: 860, loss_D: 0.0073, loss_G: 6.1501;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0070 train G: D(G(z))： 0.0034
# epoch: 49, iter: 880, loss_D: 0.0099, loss_G: 7.2776;	 Scores: train D: D(x): 0.9991, D(G(z)): 0.0088 train G: D(G(z))： 0.0026
# epoch: 49, iter: 900, loss_D: 0.4087, loss_G: 23.2778;	 Scores: train D: D(x): 0.8066, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 49, iter: 920, loss_D: 0.0219, loss_G: 6.9893;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0190 train G: D(G(z))： 0.0022
# epoch: 49, iter: 940, loss_D: 0.0015, loss_G: 7.7569;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0013 train G: D(G(z))： 0.0009
# epoch: 49, iter: 960, loss_D: 0.0288, loss_G: 5.6496;	 Scores: train D: D(x): 0.9946, D(G(z)): 0.0198 train G: D(G(z))： 0.0076
# epoch: 49, iter: 980, loss_D: 0.0008, loss_G: 8.0018;	 Scores: train D: D(x): 1.0000, D(G(z)): 0.0007 train G: D(G(z))： 0.0007
# epoch: 49, iter: 1000, loss_D: 0.0564, loss_G: 4.8059;	 Scores: train D: D(x): 0.9673, D(G(z)): 0.0127 train G: D(G(z))： 0.0153
# epoch: 49, iter: 1020, loss_D: 0.0004, loss_G: 10.1171;	 Scores: train D: D(x): 0.9999, D(G(z)): 0.0003 train G: D(G(z))： 0.0001
# epoch: 49, iter: 1040, loss_D: 0.0005, loss_G: 9.0818;	 Scores: train D: D(x): 0.9998, D(G(z)): 0.0004 train G: D(G(z))： 0.0002
# epoch: 49, iter: 1060, loss_D: 0.0011, loss_G: 14.0751;	 Scores: train D: D(x): 0.9989, D(G(z)): 0.0000 train G: D(G(z))： 0.0000
# epoch: 49, iter: 1080, loss_D: 0.0079, loss_G: 6.3226;	 Scores: train D: D(x): 0.9989, D(G(z)): 0.0067 train G: D(G(z))： 0.0027

# %%
plt.figure(figsize=(10, 5))
plt.plot(losses[0], label = 'generator')
plt.plot(losses[1], label = 'discriminator')
plt.title('Loss of training the gennerator and discriminator')
plt.xlabel('loss')
plt.ylabel('process')
plt.legend()
plt.savefig('/content/gdrive/My Drive/data/yyf/fashion minst/fminst_loss_e50_%d.png' % CONFIG.EPOCHS)
plt.show()

for i, img in enumerate(imgs):
    grid_img = util.make_figure_grid(img, 8, bright=0)
    print(i)
    plt.figure(figsize=(8, 8))
    plt.imshow(grid_img)
    plt.imsave('/content/gdrive/My Drive/data/yyf/fashion minst/fminst_e50_%d.png' % i, grid_img)
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
